# %%
import os
import sys
os.environ["PYSPARK_PYTHON"]='/opt/anaconda/envs/bd9/bin/python'
os.environ["SPARK_HOME"]='/usr/hdp/current/spark2-client'
os.environ["PYSPARK_SUBMIT_ARGS"]='--num-executors 3 pyspark-shell'

spark_home = os.environ.get('SPARK_HOME', None)

sys.path.insert(0, os.path.join(spark_home, 'python'))
sys.path.insert(0, os.path.join(spark_home, 'python/lib/py4j-0.10.7-src.zip'))

# %%
from pyspark import SparkConf
from pyspark.sql import SparkSession

conf = SparkConf()
conf.set("spark.app.name", "lab3") 

spark = SparkSession.builder.config(conf=conf).getOrCreate()

# %%
from pyspark.sql import functions as F
from pyspark.ml.feature import VectorAssembler
from pyspark.ml.classification import GBTClassifier
from pyspark.ml.classification import LogisticRegression

# %%
df_train = (spark.read
                 .format("csv")
                 .option("header", True)
                 .option("inferSchema", True)
                 .load("/labs/slaba03/laba03_train.csv"))

# %%
df_test = (spark.read
                 .format("csv")
                 .option("header", True)
                 .option("inferSchema", True)
                 .load("/labs/slaba03/laba03_test.csv"))

# %% [markdown]
# ## EDA

# %%
df_train.count()
# Out:
# 5032624

# %%
df_train.select("user_id").distinct().count()
# Out:
# 1941

# %%
df_train.select("item_id").distinct().count()
# Out:
# 3704

# %% [markdown]
# ## Генерация фичей

# %% [markdown]
# ### train

# %%
# фичи насколько интенсивно покупает пользователь
df_user_purch_stat = (df_train.groupBy("user_id")
                              .agg(F.mean("purchase").alias("user_avg_purch"),
                                   F.sum("purchase").alias("user_sum_purch")))

# %%
# фичи насколько интенсивно покупают айтеты
df_item_purch_stat = (df_train.groupBy("item_id")
                              .agg(F.mean("purchase").alias("item_avg_purch"),
                               F.sum("purchase").alias("item_sum_purch")))

# %%
df_train = (df_train.join(df_user_purch_stat, on="user_id", how="left")
                    .join(df_item_purch_stat, on="item_id", how="left"))

# %%
features = ["user_avg_purch", 
            "user_sum_purch", 
            "item_avg_purch", 
            "item_sum_purch"]

vectorAssembler = VectorAssembler(inputCols=features,
                                  outputCol="features")
                                  
df_train = vectorAssembler.transform(df_train)

# %% [markdown]
# ### test

# %%
df_test = (df_test.join(df_user_purch_stat, on="user_id", how="left")
                  .join(df_item_purch_stat, on="item_id", how="left"))

# %%
df_test = vectorAssembler.transform(df_test)

# %% [markdown]
# ## Обучение модели

# %%
lr = LogisticRegression(featuresCol='features', labelCol='purchase', predictionCol='prediction', maxIter=10000)
lr = lr.fit(df_train)

predict = lr.transform(df_test)
predict = predict.orderBy(predict.user_id, predict.item_id)
pred_pd_df = predict.select(["user_id","item_id","probability"]).toPandas()
pred_pd_df["purchase"] = pred_pd_df["probability"].apply(lambda arr: arr[1])

final = pred_pd_df[["user_id","item_id","purchase"]]

# %%
final
# Out:
#          user_id  item_id  purchase
# 0           1654      336  0.001193
# 1           1654      678  0.001193
# 2           1654      691  0.001193
# 3           1654      696  0.001388
# 4           1654      763  0.001271
# 5           1654      795  0.002052
# 6           1654      861  0.001269
# 7           1654     1137  0.001634
# 8           1654     1159  0.001356
# 9           1654     1428  0.001279
# 10          1654     1685  0.001337
# 11          1654     1686  0.001272
# 12          1654     1704  0.001445
# 13          1654     2093  0.001193
# 14          1654     2343  0.001271
# 15          1654     2451  0.001193
# 16          1654     2469  0.003081
# 17          1654     2603  0.001281
# 18          1654     2609  0.001193
# 19          1654     2621  0.001339
# 20          1654     2683  0.001731
# 21          1654     2695  0.001282
# 22          1654     2696  0.001272
# 23          1654     2773  0.001477
# 24          1654     2855  0.001374
# 25          1654     2990  0.001273
# 26          1654     3055  0.001193
# 27          1654     3066  0.002299
# 28          1654     3110  0.001271
# 29          1654     3147  0.001378
# ...          ...      ...       ...
# 2156810   941450   100453  0.001149
# 2156811   941450   100459  0.001030
# 2156812   941450   100478  0.001101
# 2156813   941450   100480  0.001111
# 2156814   941450   100483  0.001113
# 2156815   941450   100492  0.001101
# 2156816   941450   100500  0.001204
# 2156817   941450   100571  0.001173
# 2156818   941450   100667  0.001094
# 2156819   941450   100759  0.001099
# 2156820   941450   101103  0.001030
# 2156821   941450   101352  0.001096
# 2156822   941450   101528  0.001109
# 2156823   941450   101529  0.001030
# 2156824   941450   101822  0.001030
# 2156825   941450   101832  0.001030
# 2156826   941450   101870  0.001030
# 2156827   941450   101958  0.001105
# 2156828   941450   102088  0.001030
# 2156829   941450   102279  0.001107
# 2156830   941450   102431  0.001108
# 2156831   941450   102603  0.001088
# 2156832   941450   102640  0.001094
# 2156833   941450   102641  0.001030
# 2156834   941450   102651  0.001139
# 2156835   941450   102966  0.001104
# 2156836   941450   103589  0.001169
# 2156837   941450   103762  0.001095
# 2156838   941450   103876  0.001093
# 2156839   941450   104016  0.001087
#
# [2156840 rows x 3 columns]

# %%
final.to_csv("/data/home/olga.pogodina/lab03.csv")

# %%
spark.stop()
